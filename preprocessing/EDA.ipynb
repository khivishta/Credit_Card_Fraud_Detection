# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # convert zip to csv

# %%
# import zipfile

# # Path to the ZIP file
# zip_file_path = (
#     "../data/archive.zip"  # Replace 'path/to/archive.zip' with the actual path
# )

# %%
# # Destination directory to extract the contents
# extract_to_directory = (
#     "../data"  # Replace 'destination/folder' with the desired directory
# )

# # Open and extract the contents of the ZIP file
# with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
#     zip_ref.extractall(extract_to_directory)
#     print(f"Contents of '{zip_file_path}' extracted to '{extract_to_directory}'.")

# %% [markdown]
# # open and visualise the csv file

# %%
file_path = "../data/creditcard_2023.csv"

# %%
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(file_path)

# Display the column headers and the first few rows of the DataFrame
data.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# 1. Display Basic Information
print("Basic Information about the DataFrame:")
print(data.info())

# 2. Summary Statistics
print("\nSummary Statistics:")
print(data.describe())
# Out:
# Basic Information about the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
# ...

# %%
# 3. Class Distribution
class_distribution = data["Class"].value_counts()
print("\nClass Distribution:")
print(class_distribution)
# Out:
# Class Distribution:
# 0    284315
# 1    284315
# Name: Class, dtype: int64

# %%
# 4. Correlation Analysis (if features are anonymized)
correlation_matrix = data.corr()
plt.figure(figsize=(20, 18))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# 5. Visualization - Example: Histograms
data.hist(figsize=(22, 19), bins=20)
plt.suptitle("Histograms of Features")
plt.show()
